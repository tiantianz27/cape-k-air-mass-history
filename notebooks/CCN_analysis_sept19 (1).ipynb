# %%
import act
import pandas as pd

# %%
df_ccn=pd.read_csv('../data/ccn/kcgccn100X30.a1.20240919.000000.custom.csv',
                  index_col=0)

# %%
df_ccn.index = pd.to_datetime(df_ccn.index)

# %%
df_ccn
# Out:
#                       base_time          time_offset  \
# time
# 2024-09-19 00:00:00  2024-09-19  2024-09-19 00:00:00
# 2024-09-19 00:00:01  2024-09-19  2024-09-19 00:00:01
# 2024-09-19 00:00:02  2024-09-19  2024-09-19 00:00:02
# 2024-09-19 00:00:03  2024-09-19  2024-09-19 00:00:03
# 2024-09-19 00:00:04  2024-09-19  2024-09-19 00:00:04
# ...                         ...                  ...
# 2024-09-19 23:59:55  2024-09-19  2024-09-19 23:59:55
# 2024-09-19 23:59:56  2024-09-19  2024-09-19 23:59:56
# 2024-09-19 23:59:57  2024-09-19  2024-09-19 23:59:57
# 2024-09-19 23:59:58  2024-09-19  2024-09-19 23:59:58
# 2024-09-19 23:59:59  2024-09-19  2024-09-19 23:59:59
#
#                      CCN_supersaturation_set_point  CCN_temp_unstable  \
# time
# 2024-09-19 00:00:00                            0.6                0.0
# 2024-09-19 00:00:01                            0.6                0.0
# 2024-09-19 00:00:02                            0.6                0.0
# ...

# %%
df_ccn['N_CCN'].plot()
# Out:
# <Axes: xlabel='time'>

# %%
df_ccn['N_CCN'].resample('1min').mean().plot()
# Out:
# <Axes: xlabel='time'>
